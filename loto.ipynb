# %%
import pandas as pd
import numpy as np

# %%
loto = pd.read_excel('/content/Lotofácil.xlsx')

# %%
loto
# Out:
#       Concurso Data Sorteio  Bola1  Bola2  Bola3  Bola4  Bola5  Bola6  Bola7  \
# 0            1   29/09/2003      2      3      5      6      9     10     11
# 1            2   06/10/2003      1      4      5      6      7      9     11
# 2            3   13/10/2003      1      4      6      7      8      9     10
# 3            4   20/10/2003      1      2      4      5      8     10     12
# 4            5   27/10/2003      1      2      4      8      9     11     12
# ...        ...          ...    ...    ...    ...    ...    ...    ...    ...
# 2930      2936   23/10/2023      1      4      8      9     10     11     12
# 2931      2939   26/10/2023      2      3      5      6      7      9     10
# 2932      2940   27/10/2023      1      2      5      7      8      9     11
# 2933      2942   30/10/2023      4      5      6      7      8      9     10
# 2934      2943   31/10/2023      1      4      5      8      9     10     11
#
#       Bola8  ...  Rateio 13 acertos  Ganhadores 12 acertos  Rateio 12 acertos  \
# 0        13  ...            R$10,00                  48807             R$4,00
# 1        12  ...            R$10,00                  81252             R$4,00
# 2        11  ...            R$10,00                  96244             R$4,00
# 3        13  ...            R$10,00                 123912             R$4,00
# 4        13  ...            R$10,00                 195636             R$4,00
# ...     ...  ...                ...                    ...                ...
# 2930     13  ...            R$30,00                  99583            R$12,00
# 2931     11  ...            R$30,00                 109808            R$12,00
# 2932     12  ...            R$30,00                 182361            R$12,00
# 2933     14  ...            R$30,00                 132813            R$12,00
# 2934     12  ...            R$30,00                  83612            R$12,00
#
#       Ganhadores 11 acertos  Rateio 11 acertos  Acumulado 15 acertos  \
# 0                    257593             R$2,00                R$0,00
# 1                    478188             R$2,00                R$0,00
# 2                    608211             R$2,00                R$0,00
# 3                    706657             R$2,00                R$0,00
# 4                    860992             R$2,00                R$0,00
# ...                     ...                ...                   ...
# 2930                 500260             R$6,00                R$0,00
# 2931                 550891             R$6,00        R$2.084.587,94
# 2932                1035328             R$6,00                R$0,00
# 2933                 793900             R$6,00                R$0,00
# 2934                 490449             R$6,00        R$1.591.791,81
#
#       Arrecadacao Total  Estimativa Prêmio  \
# 0                R$0,00             R$0,00
# 1                R$0,00             R$0,00
# 2                R$0,00             R$0,00
# 3                R$0,00             R$0,00
# 4                R$0,00             R$0,00
# ...                 ...                ...
# 2930    R$17.891.493,00     R$1.700.000,00
# 2931    R$17.047.989,00     R$5.000.000,00
# 2932    R$34.343.916,00     R$1.700.000,00
# 2933    R$29.345.181,00     R$1.700.000,00
# 2934    R$17.988.999,00     R$4.000.000,00
#
#      Acumulado sorteio especial Lotofácil da Independência  \
# 0                                                R$0,00
# 1                                                R$0,00
# 2                                                R$0,00
# 3                                                R$0,00
# 4                                                R$0,00
# ...                                                 ...
# 2930                                    R$16.119.011,23
# 2931                                    R$17.000.954,96
# 2932                                    R$17.636.677,22
# 2933                                    R$18.622.896,02
# 2934                                    R$19.008.006,96
#
#                                              Observação
# 0     Estimativa de prêmio (15 ACERTOS) próximo conc...
# 1     ESTIMATIVA DE PRÊMIO PARA O PRÓXIMO CONCURSO (...
# 2     Estimativa de prêmio (15 ACERTOS) próximo conc...
# 3     Estimativa de prêmio (15 ACERTOS) próximo conc...
# 4     Estimativa de prêmio para o próximo concurso (...
# ...                                                 ...
# 2930                                                NaN
# 2931                                                NaN
# 2932                                                NaN
# 2933                                                NaN
# 2934                                                NaN
#
# [2935 rows x 33 columns]

# %%
loto.columns
# Out:
# Index(['Concurso', 'Data Sorteio', 'Bola1', 'Bola2', 'Bola3', 'Bola4', 'Bola5',
#        'Bola6', 'Bola7', 'Bola8', 'Bola9', 'Bola10', 'Bola11', 'Bola12',
#        'Bola13', 'Bola14', 'Bola15', 'Ganhadores 15 acertos', 'Cidade / UF',
#        'Rateio 15 acertos', 'Ganhadores 14 acertos', 'Rateio 14 acertos',
#        'Ganhadores 13 acertos', 'Rateio 13 acertos', 'Ganhadores 12 acertos',
#        'Rateio 12 acertos', 'Ganhadores 11 acertos', 'Rateio 11 acertos',
#        'Acumulado 15 acertos', 'Arrecadacao Total', 'Estimativa Prêmio',
#        'Acumulado sorteio especial Lotofácil da Independência', 'Observação'],
#       dtype='object')

# %%
bolas = loto[['Bola1', 'Bola2', 'Bola3', 'Bola4', 'Bola5',
       'Bola6', 'Bola7', 'Bola8', 'Bola9', 'Bola10', 'Bola11', 'Bola12',
       'Bola13', 'Bola14', 'Bola15']]

# %%
bolas
# Out:
#       Bola1  Bola2  Bola3  Bola4  Bola5  Bola6  Bola7  Bola8  Bola9  Bola10  \
# 0         2      3      5      6      9     10     11     13     14      16
# 1         1      4      5      6      7      9     11     12     13      15
# 2         1      4      6      7      8      9     10     11     12      14
# 3         1      2      4      5      8     10     12     13     16      17
# 4         1      2      4      8      9     11     12     13     15      16
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 2930      1      4      8      9     10     11     12     13     16      18
# 2931      2      3      5      6      7      9     10     11     12      13
# 2932      1      2      5      7      8      9     11     12     13      14
# 2933      4      5      6      7      8      9     10     14     16      17
# 2934      1      4      5      8      9     10     11     12     15      16
#
#       Bola11  Bola12  Bola13  Bola14  Bola15
# 0         18      20      23      24      25
# 1         16      19      20      23      24
# 2         16      17      20      23      24
# 3         18      19      23      24      25
# 4         19      20      23      24      25
# ...      ...     ...     ...     ...     ...
# 2930      19      20      21      23      24
# 2931      17      18      20      22      23
# 2932      15      20      21      24      25
# 2933      18      19      20      23      25
# 2934      17      18      19      20      25
#
# [2935 rows x 15 columns]

# %%
matriz = bolas.values

# %%
matriz
# Out:
# array([[ 2,  3,  5, ..., 23, 24, 25],
#        [ 1,  4,  5, ..., 20, 23, 24],
#        [ 1,  4,  6, ..., 20, 23, 24],
#        ...,
#        [ 1,  2,  5, ..., 21, 24, 25],
#        [ 4,  5,  6, ..., 20, 23, 25],
#        [ 1,  4,  5, ..., 19, 20, 25]])

# %%
# Obtém os valores únicos e suas contagens
valores_unicos, contagem = np.unique(matriz, return_counts=True)

# Cria um DataFrame para armazenar os valores únicos e suas contagens
dados_contagem = pd.DataFrame({'Valor': valores_unicos, 'Contagem': contagem})

# Ordena o DataFrame pela coluna 'Contagem' em ordem decrescente
dados_contagem = dados_contagem.sort_values(by='Contagem', ascending=False)

# Obtém os valores mais repetidos
valores_mais_repetidos = dados_contagem[dados_contagem['Contagem'] == dados_contagem['Contagem'].max()]

print("Valores mais repetidos:")
print(valores_mais_repetidos)

#O código acima cria um DataFrame chamado dados_contagem que armazena os valores únicos e suas contagens.
#Em seguida, ele classifica o DataFrame com base na coluna de contagem em ordem decrescente.
#Por fim, ele obtém os valores mais repetidos, que são aqueles com a contagem máxima.
#Os valores mais repetidos serão armazenados no DataFrame valores_mais_repetidos,
#que pode ser impresso ou usado conforme necessário.
# Out:
# Valores mais repetidos:
#     Valor  Contagem
# 19     20      1841

# %%
# Obtém os valores únicos e suas contagens
valores_unicos, contagem = np.unique(matriz, return_counts=True)

# Verifica quais valores têm contagens maiores que 1 (são repetidos)
valores_repetidos = valores_unicos[contagem > 1755]

print("Valores repetidos:")
print(valores_repetidos)
# Out:
# Valores repetidos:
# [ 1  3  4  5  9 10 11 12 13 14 20 22 24 25]
